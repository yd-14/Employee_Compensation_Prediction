# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('data/Employee_Compensation_SF.csv'))
df.head()
# Out:
#    Organization Group Code Job Family Code Job Code Year Type  Year  \
# 0                        3            1400     1404    Fiscal  2019
# 1                        3            2900     2918    Fiscal  2019
# 2                        3            2900     2918    Fiscal  2019
# 3                        3            2900     2918    Fiscal  2019
# 4                        3            9900     9910    Fiscal  2019
#
#                          Organization Group Department Code      Department  \
# 0  Human Welfare & Neighborhood Development             HSA  Human Services
# 1  Human Welfare & Neighborhood Development             HSA  Human Services
# 2  Human Welfare & Neighborhood Development             HSA  Human Services
# 3  Human Welfare & Neighborhood Development             HSA  Human Services
# 4  Human Welfare & Neighborhood Development             HSA  Human Services
#
#    Union Code                   Union  ... Employee Identifier  Salaries  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923615 entries, 0 to 923614
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Organization Group Code  923615 non-null  int64
#  1   Job Family Code          923615 non-null  object
#  2   Job Code                 923615 non-null  object
#  3   Year Type                923615 non-null  object
#  4   Year                     923615 non-null  int64
#  5   Organization Group       923615 non-null  object
#  6   Department Code          923613 non-null  object
#  7   Department               923613 non-null  object
#  8   Union Code               923435 non-null  float64
#  9   Union                    923436 non-null  object
#  10  Job Family               923615 non-null  object
#  11  Job                      923610 non-null  object
#  12  Employee Identifier      923615 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Organization Group Code      0
# Job Family Code              0
# Job Code                     0
# Year Type                    0
# Year                         0
# Organization Group           0
# Department Code              2
# Department                   2
# Union Code                 180
# Union                      179
# Job Family                   0
# Job                          5
# Employee Identifier          0
# Salaries                     0
# Overtime                     0
# Other Salaries               0
# Total Salary                 0
# Retirement                   0
# Health and Dental            0
# Other Benefits               0
# Total Benefits               0
# Total Compensation           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 923428 entries, 0 to 923614
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Organization Group Code  923428 non-null  int64
#  1   Job Family Code          923428 non-null  object
#  2   Job Code                 923428 non-null  object
#  3   Year Type                923428 non-null  object
#  4   Year                     923428 non-null  int64
#  5   Organization Group       923428 non-null  object
#  6   Department Code          923428 non-null  object
#  7   Department               923428 non-null  object
#  8   Union Code               923428 non-null  float64
#  9   Union                    923428 non-null  object
#  10  Job Family               923428 non-null  object
#  11  Job                      923428 non-null  object
#  12  Employee Identifier      923428 non-null  int64
# ...

# %%
if (df['Salaries'] == 0).any():
    print("yes")

print((df['Salaries'] == 0).sum())
# Out:
# yes
# 14515

# %%
df=df[df['Salaries'] != 0]

# %%
df['Overtime Amount'] = pd.Series(df.Overtime / df.Salaries)
df['Overtime Amount'] = pd.cut(df['Overtime Amount'], 5, labels = ['few overtime', 'less than average overtime', 'average overtime', 'more than average overtime', 'many overtime'])

df['Retirement Amount'] = pd.Series(df.Retirement / df.Salaries)
df['Retirement Amount'] = pd.cut(df['Retirement Amount'], 5, labels = ['few retirement', 'less than average retirement', 'average retirement', 'more than average retirement', 'many retirement'])

df['Health and Dental Amount'] = pd.Series(df['Health and Dental'] / df.Salaries)
df['Health and Dental Amount'] = pd.cut(df['Health and Dental Amount'], 5, labels = ['few Health/Dental', 'less than average Health/Dental', 'average Health/Dental', 'more than average Health/Dental', 'many Health/Dental'])

df['Other Benefits Amount'] = pd.Series(df['Other Benefits'] / df.Salaries)
df['Other Benefits Amount'] = pd.cut(df['Other Benefits Amount'], 5, labels = ['few Other Benefits', 'less than average Other Benefits', 'average Other Benefits', 'more than average Other Benefits', 'many Other Benefits'])

# %%
independent_var = ['Organization Group Code', 'Job Family Code', 'Job Code', 'Year Type', 'Year', 'Department Code', 'Union Code']
drop_columns= ['Year Type', 'Organization Group', 'Department', 'Union', 'Job Family', 'Job', 'Employee Identifier', 'Overtime', 'Other Salaries', 'Total Salary', 'Retirement', 'Health and Dental', 'Other Benefits', 'Total Benefits', 'Total Compensation']

# %%
new_df = df.drop(columns = drop_columns)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908913 entries, 0 to 923614
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Organization Group Code   908913 non-null  int64
#  1   Job Family Code           908913 non-null  object
#  2   Job Code                  908913 non-null  object
#  3   Year                      908913 non-null  int64
#  4   Department Code           908913 non-null  object
#  5   Union Code                908913 non-null  float64
#  6   Salaries                  908913 non-null  float64
#  7   Overtime Amount           908913 non-null  category
#  8   Retirement Amount         908913 non-null  category
#  9   Health and Dental Amount  908913 non-null  category
#  10  Other Benefits Amount     908913 non-null  category
# dtypes: category(4), float64(2), int64(2), object(3)
# memory usage: 58.9+ MB

# %%
new_df.columns
# Out:
# Index(['Organization Group Code', 'Job Family Code', 'Job Code', 'Year',
#        'Department Code', 'Union Code', 'Salaries', 'Overtime Amount',
#        'Retirement Amount', 'Health and Dental Amount',
#        'Other Benefits Amount'],
#       dtype='object')

# %%
new_df.head()
# Out:
#    Organization Group Code Job Family Code Job Code  Year Department Code  \
# 0                        3            1400     1404  2019             HSA
# 1                        3            2900     2918  2019             HSA
# 2                        3            2900     2918  2019             HSA
# 3                        3            2900     2918  2019             HSA
# 4                        3            9900     9910  2019             HSA
#
#    Union Code  Salaries Overtime Amount Retirement Amount  \
# 0       790.0  60720.01    few overtime    few retirement
# 1       535.0  89106.03    few overtime    few retirement
# 2       535.0  85581.11    few overtime    few retirement
# 3       535.0  89106.07    few overtime    few retirement
# 4       790.0   2585.45    few overtime    few retirement
#
#   Health and Dental Amount Other Benefits Amount
# 0        few Health/Dental    few Other Benefits
# 1        few Health/Dental    few Other Benefits
# ...

# %%
# new_df=new_df.drop(columns=['Year Type'])

# %%
# new_df['Job Family Code'].nunique()

# %%
new_df.to_csv('data/Employee_Compensation.csv', index=False)

# %%
# df2= pd.DataFrame(pd.read_csv('D:/ThirdEyeData/Employee_Compensation_Prediction/artifacts/train_data.csv'))
# df2.head()
# Out:
#    Organization Group Code Job Family Code Job Code  Year Department Code  \
# 0                        1            8300     8320  2023             JUV
# 1                        2            5200     5262  2019             DPW
# 2                        6            9700     9775  2016             MYR
# 3                        1            Q000     Q002  2019             POL
# 4                        2            9100     9139  2021             MTA
#
#    Union Code   Salaries Overtime Amount Retirement Amount  \
# 0       790.0   91273.60    few overtime    few retirement
# 1        21.0  166188.12    few overtime    few retirement
# 2       790.0  112897.82    few overtime    few retirement
# 3       911.0   87119.84    few overtime    few retirement
# 4       200.0  108050.00    few overtime    few retirement
#
#   Health and Dental Amount Other Benefits Amount
# 0        few Health/Dental    few Other Benefits
# 1        few Health/Dental    few Other Benefits
# ...
